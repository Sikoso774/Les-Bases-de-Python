# %% [markdown]
# # Les différents types d'erreurs

# %% [markdown]
# ## Les erreurs à l'exécution

# %% [markdown]
# - A/ SyntaxError

# %%
# La sensibilité à la casse

maj="ABC"
if not maj = "HH": # <----- Il fallait mettre == à la place de =
print("Echec")
# Out:
#   Cell In[1], line 4
#     if not maj = "HH": # <----- Il fallait mettre == à la place de =
#                ^
# SyntaxError: invalid syntax

# %%
# Les deux points

u = []
for i in range(1,9); # <----- Attention ! Il faut mettre un ":" au lieu de ";"
    u.append(i)
print(u)
# Out:
#   Cell In[2], line 4
#     for i in range(1,9); # <----- Attention ! Il faut mettre un ":" au lieu de ";"
#                        ^
# SyntaxError: invalid syntax

# %%
# Les guillemets

print("Ousmane Dembélé)
# Attention aux guillemets avec les <str> !
# Out:
#   Cell In[3], line 3
#     print("Ousmane Dembélé)
#           ^
# SyntaxError: unterminated string literal (detected at line 3)

# %% [markdown]
# - B/ NameError

# %%
# bonjour = "Bonjour" <----- La variable bonjour n'est pas définie
print(bonjour) # <----- Il n'y a aucune variable bonjour...
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # bonjour = "Bonjour" <----- La variable bonjour n'est pas définie
# ----> 2 print(bonjour) # <----- Il n'y a aucune variable bonjour...
#
# NameError: name 'bonjour' is not defined

# %% [markdown]
# C/ TypeError

# %%
"2"+ 2 # <----- Impossible de faire le calcul car ils ne sont pas du mm <type>
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 "2"+ 2 # <----- Impossible de faire le calcul car ils ne sont pas du mm <type>
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ## Les erreurs sémantiques

# %%
# Il faut que le programme ait de la logique... C'est évident
# Il faut utiliser un débugger

# %% [markdown]
# # Quelques modules et fonctions

# %% [markdown]
# ## Le module random

# %%
import random # <---- Importation de la bibliothèque random

n = random.randint(0,1) # <---- <int> aléatoire entre 0 et 1 (INCLUS)
m = random.randint(0,1) # <---- <int> aléatoire entre 0 et 1 (INCLUS)
print(n)
print(m)
# Out:
# 0
# 1

# %%
n = random.uniform(0,1) # <---- <float> aléatoire entre 0 et 1 (INCLUS)
m = random.uniform(0,1) # <---- <float> aléatoire entre 0 et 1 (INCLUS)
print(n) 
print(m)
# Out:
# 0.1792421207546172
# 0.5674750684064498

# %%
n = random.randrange(1) # <---- <int> aléatoire entra 0 et 1 (EXCLU)
print(n)
# >>> Il affichera toujours 0 car la fct randrange(1) exclut la valeur 1 dans l'intervalle
# Out:
# 0

# %%
m = random.randrange(0,101,5) # <---- <int> aléatoire entre 0 et 101 (EXCLU) avec un pas de 5
print(m)
# >>> Il affichera un <int> entre 0 et 100 avec un pas de 5. (donc un multiple de 5)
# Out:
# 70

# %% [markdown]
# ## Le module os

# %%
# La bibliothèque "os" est utilisée pour créer ou supprimer des fichiers
import os  # <---- Importation de la bibliothèque os 

chemin = "/Users/zolen/Documents/Informatique_Etude/Python/"

dossier = os.path.join(chemin, "Cours") # <---- La fonction gère les slashs elle-même :)
dossier_1= os.path.join(chemin, "dossier", "new_folder")

print(dossier_1) # <---- Affiche le chemin complet du dossier "Cours"
# >>> Permet de rejoindre le dossier "Cours" dans le dossier Python
# Out:
# /Users/zolen/Documents/Informatique_Etude/Python/dossier\new_folder

# %%
os.makedirs(dossier_1)
print("Le dossier a été généré :)")
# Out:
# Le dossier a été généré :)

# %%
os.makedirs(dossier_1) # <----- C'est une erreur car le dossier a déjà été crée
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 os.makedirs(dossier_1) # <----- C'est une erreur car le dossier a déjà été crée
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [WinError 183] Impossible de créer un fichier déjà existant: '/Users/zolen/Documents/Informatique_Etude/Python/dossier\\new_folder'

# %%
# Pour créer un fichier sans se soucier de l'erreur :

dossier_2 = os.path.join(chemin,"Autre_dossier")
if not os.path.exists(dossier_2):
    os.makedirs(dossier_2)
    print("Le dossier a bien été générée :)")
else:
    print("Le dossier existe déjà")
# Out:
# Le dossier a bien été générée :)

# %%
if os.makedirs(dossier_2,exist_ok=True): # <----- "exist_ok" permet de ne pas avoir d'erreur mm si le fichier existe
    phrase = "Bonjour, le dossier a été créé"
    print(phrase)

# %%
# Comment supprimer un fichier ?

os.removedirs(dossier_2) # <----- Le dossier "Autre_dossier sera supprimée"
print("Le dossier a bien été supprimée :)")
# Out:
# Le dossier a bien été supprimée :)

# %%
os.removedirs(dossier_2) # <---- Le dossier a déja été supprimée 
# >>> Il ne détectera pas un fichier qui n'existe pas (logique)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 os.removedirs(dossier_2) # <---- Le dossier a déja été supprimée
#       2 # >>> Il ne détectera pas un fichier qui n'existe pas (logique)
#
# File <frozen os>:243, in removedirs(name)
#
# FileNotFoundError: [WinError 2] Le fichier spécifié est introuvable: '/Users/zolen/Documents/Informatique_Etude/Python/Autre_dossier'

# %%
# Il n'existe aucun argument exist_OK avec removedirs(). 
# Il faut une structure conditionnelle

if os.path.exists(dossier_2):
    os.removedirs(dossier_2)
    print("L'autre dossier a bien été supprimée :)")
else:
    print("Déja supprimée ;)")
# Out:
# Déja supprimée ;)

# %% [markdown]
# ## Les fonctions utiles

# %%
# La fonction dir()
print(dir(random)) # <---- affichera toutes les fonctions que l'on peut utiliser sur random{}
# Out:
# ['BPF', 'LOG4', 'NV_MAGICCONST', 'RECIP_BPF', 'Random', 'SG_MAGICCONST', 'SystemRandom', 'TWOPI', '_ONE', '_Sequence', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_accumulate', '_acos', '_bisect', '_ceil', '_cos', '_e', '_exp', '_fabs', '_floor', '_index', '_inst', '_isfinite', '_lgamma', '_log', '_log2', '_os', '_pi', '_random', '_repeat', '_sha512', '_sin', '_sqrt', '_test', '_test_generator', '_urandom', '_warn', 'betavariate', 'binomialvariate', 'choice', 'choices', 'expovariate', 'gammavariate', 'gauss', 'getrandbits', 'getstate', 'lognormvariate', 'normalvariate', 'paretovariate', 'randbytes', 'randint', 'random', 'randrange', 'sample', 'seed', 'setstate', 'shuffle', 'triangular', 'uniform', 'vonmisesvariate', 'weibullvariate']

# %%
# La fonction help()
import pygame
help(pygame) # <---- Affiche la documentation de pygame
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.10)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Help on package pygame:
#
# NAME
#     pygame
#
# DESCRIPTION
#     Pygame is a set of Python modules designed for writing games.
#     It is written on top of the excellent SDL library. This allows you
#     to create fully featured games and multimedia programs in the python
#     language. The package is highly portable, with games running on
#     Windows, MacOS, OS X, BeOS, FreeBSD, IRIX, and Linux.
#
# PACKAGE CONTENTS
#     __pyinstaller (package)
#     _camera
#     _camera_opencv
#     _camera_vidcapture
#     _freetype
#     _sdl2 (package)
#     _sprite
#     base
#     bufferproxy
#     camera
#     color
#     colordict
#     constants
#     cursors
#     display
#     draw
#     draw_py
#     event
#     examples (package)
#     fastevent
#     font
#     freetype
#     ftfont
#     gfxdraw
#     image
#     imageext
#     joystick
#     key
# ...

# %%
# La fonction pprint()
from pprint import pprint
pprint(dir(random))
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  '_warn',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %% [markdown]
# # Les objets callables

# %%
import os
from pprint import pprint
print(callable(os)) # <---- On ne peut pas appeler un module 
# >>> False
print(callable(pprint))
# >>> True
print(callable(os.name)) # <---- On ne peut pas appeler os.name
print(os.name())
# Out:
# False
# True
# False
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 8
#       6 # >>> True
#       7 print(callable(os.name)) # <---- On ne peut pas appeler os.name
# ----> 8 print(os.name())
#
# TypeError: 'str' object is not callable

# %% [markdown]
# &#169; <b>Zoléni KOKOLO ZASSI</b>
#
# 28 mars 2025, mis à jour le 15 juillet 2025
