# %% [markdown]
# # Test pour afficher une image

# %% [markdown]
# ![Exemple](pythoned.png)

# %% [markdown]
# # Un peu plus complexe...

# %%
import base64

def convertir_image_en_base64(chemin_image):
    """
    Lit une image à partir de son chemin d'accès et la convertit en une chaîne Base64.

    Args:
        chemin_image (str): Le chemin d'accès au fichier image.

    Returns:
        str: La chaîne Base64 de l'image, ou None en cas d'erreur.
    """
    try:
        with open(chemin_image, "rb") as image_file:
            encoded_string = base64.b64encode(image_file.read()).decode('utf-8')
        return encoded_string
    except FileNotFoundError:
        print(f"Erreur : Le fichier image '{chemin_image}' n'a pas été trouvé.")
        return None
    except Exception as e:
        print(f"Erreur lors de la conversion de l'image en Base64 : {e}")
        return None

# Instructions d'utilisation :
# 1. Assurez-vous d'avoir l'image que vous souhaitez convertir enregistrée sur votre ordinateur.
# 2. Remplacez 'chemin_vers_votre_image.png' (ou l'extension appropriée) par le chemin réel de votre fichier image.

chemin_de_l_image = 'Image_test.png'
base64_data = convertir_image_en_base64(chemin_de_l_image)

if base64_data:
    print("Voici la chaîne Base64 de votre image :")
    print(base64_data)
    print("\n")
    print("Vous pouvez utiliser cette chaîne dans votre Markdown comme ceci :")
    print("```markdown")
    # Pour une image PNG
    print(f"![Votre description de l'image](data:image/png;base64,{base64_data})")
    # Si votre image est un JPEG, remplacez 'png' par 'jpeg'
    # print(f"![Votre description de l'image](data:image/jpeg;base64,{base64_data})")
    print("```")
# Out:
# Voici la chaîne Base64 de votre image :
# ...
#
#
# Vous pouvez utiliser cette chaîne dans votre Markdown comme ceci :
# ```markdown
# ![Votre description de l'image](data:image/png;base64,...)
# ```

# %% [markdown]
# # OUI !!!!

# %% [markdown]
# ![Le_TEST](data:image/png;base64,...)
